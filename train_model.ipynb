# %%
#Import library

# %matplotlib inline
import numpy as np
import os
import cv2

import matplotlib
import matplotlib.pyplot as plt
import math

import keras
from keras.layers import (Input, Activation, Conv3D, Dense, Dropout, Flatten, 
                          MaxPooling3D, BatchNormalization, AveragePooling3D, 
                          Reshape, Lambda, GlobalAveragePooling3D, Concatenate,
                          ReLU, Add)

from keras.losses import categorical_crossentropy
from keras.models import Sequential, Model, load_model
from keras.optimizers import SGD, Adam
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from keras.utils.layer_utils import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file

from sklearn.model_selection import train_test_split

from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from keras.callbacks import CSVLogger

# Set TensorFlow session
from tensorflow.compat.v1.keras.backend import set_session

# %%
def plot_history(history, result_dir):
    '''
    Plots the accuracy and loss graphs of train and val and saves them.
    '''

    plt.plot(history.history['accuracy'], marker='.')
    plt.plot(history.history['val_accuracy'], marker='.')
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
    plt.savefig(os.path.join(result_dir, 'model_accuracy.png'))
    plt.show()

    plt.plot(history.history['loss'], marker='.')
    plt.plot(history.history['val_loss'], marker='.')
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss', 'val_loss'], loc='upper right')
    plt.savefig(os.path.join(result_dir, 'model_loss.png'))
    plt.show();

# %%
class Videoto3D:

    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

    def video3d(self, filename):
        
        frames = []
        index = len(os.listdir(filename)) // self.depth
        images = os.listdir(filename)[::index]
        images = images[0:25]
        images.sort()

        for img in images:

            img_path = os.path.join(filename, img)
            frame = cv2.imread(img_path)
            frame = cv2.resize(frame, (self.height, self.width))
            frames.append(frame)

        return np.array(frames) / 255.0

# %%
def preprocess(video_dir, result_dir, nb_classes = 101, img_size = 224, frames = 25):
    '''
    Preprocess the videos into X and Y and saves in npz format and 
    computes input shape
    '''

    img_rows, img_cols  = img_size, img_size

    channel = 3

    files = os.listdir(video_dir)
    files.sort()

    if '.ipynb_checkpoints' in files:
        files.remove('.ipynb_checkpoints')

    X = []
    labels = []
    labellist = []

    # Obtain labels and X
    for filename in files:

        name = os.path.join(video_dir, filename)
        
        for v_files in os.listdir(name):
            
            v_file_path = os.path.join(name, v_files)
            label = filename
            if label not in labellist:
                if len(labellist) >= nb_classes:
                    continue
                labellist.append(label)
            labels.append(label)
            X.append(v_file_path)

    if not os.path.isdir(result_dir):
        os.makedir(result_dir)
    with open(os.path.join(result_dir, 'classes.txt'), 'w') as fp:
        for i in range(len(labellist)):
            fp.write('{} {}\n'.format(i, labellist[i]))

    for num, label in enumerate(labellist):
        for i in range(len(labels)):
            if label == labels[i]:
                labels[i] = num
                
    Y = np_utils.to_categorical(labels, nb_classes)

    print('X_shape:{}\tY_shape:{}'.format(len(X), Y.shape))

    input_shape = (frames, img_rows, img_cols, channel)

    return X, Y, input_shape

# %%
# %run models/slowfast.py

def resnet50(inputs, **kwargs):
    model = SlowFast_body(inputs, [3, 4, 6, 3], bottleneck, **kwargs)
    return model

# %%
# %run models/i3dinception.py

def I3DModel(model, nb_classes):

    x = model.layers[-1].output
    x = Dropout(0.5)(x)
    x = conv3d_bn(x, nb_classes, 1, 1, 1, padding='same', 
            use_bias=True, use_activation_fn=False, use_bn=False, name='Conv3d_6a_1x1')
    num_frames_remaining = int(x.shape[1])
    x = Reshape((num_frames_remaining, nb_classes))(x)
    # logits (raw scores for each class)
    x = Lambda(lambda x: K.mean(x, axis=1, keepdims=False),
                output_shape=lambda s: (s[0], s[2]))(x)
    x = Activation('softmax', name='prediction')(x)
    model = Model(model.inputs, x)
    
    return model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Downloads/HUMAN SUSPICIOUS ACTIVITY FLASK-20240929T064526Z-001/HUMAN SUSPICIOUS ACTIVITY FLASK-20240929T064526Z-001/HUMAN SUSPICIOUS ACTIVITY FLASK/models/i3dinception.py:31
#      28 from keras.layers import Lambda
#      29 from keras.layers import GlobalAveragePooling3D
# ---> 31 from keras.engine.topology import get_source_inputs
#      32 from keras.utils import layer_utils
#      33 from keras.utils.data_utils import get_file
#
# ModuleNotFoundError: No module named 'keras.engine.topology'

# %%
class batchGenerator(keras.utils.Sequence):

    def __init__(self, x_set, y_set, batch_size, vid3d):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.vid3d = vid3d

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        batch_x = []

        for video in self.x[idx * self.batch_size:(idx + 1) * self.batch_size]:
            batch_x.append(self.vid3d.video3d(video))

        batch_x = np.array(batch_x)
        batch_x = batch_x.astype('float32')
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        return batch_x, batch_y

# %%
def main(video_dir, result_dir, nb_classes = 101, batch_size = 32, epochs = 100, img_size = 224, frames = 25):

    X, Y, input_shape = preprocess(video_dir, result_dir, nb_classes, img_size, 
                                   frames)

    print("Input Shape = ", input_shape)

    vid3d = Videoto3D(img_size, img_size, frames)

    ## For i3D Inception model ##
#     i3dmodel = Inception_Inflated3d(include_top=False,
#                 weights='rgb_imagenet_and_kinetics',
#                 input_tensor=None,
#                 input_shape=input_shape,
#                 dropout_prob=0.5,
#                 endpoint_logit=False)
    
#     model = I3DModel(i3dmodel, nb_classes)
    
    ## For Slowfast model ##
    x = Input(shape = input_shape)
    model = resnet50(x, num_classes=nb_classes)

    model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.9), 
                  metrics=['accuracy'])
    
#     model = load_model('/content/drive/Shared drives/Drive 13/Dataset/Slowfast/slowfast-77-0.73.hd5')
    
    model.summary()

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.15, shuffle = True)
    
    X_train, X_val, Y_train, Y_val = train_test_split(
        X_train, Y_train, test_size=0.15, shuffle = True)

    print("X_train.shape = ", len(X_train))
    print("X_val.shape = ", len(X_val))
    print("X_test.shape = ", len(X_test))

    # MODEL CHECK POINTS #

    csv_logger = CSVLogger("/content/drive/Shared drives/Drive 13/Dataset/Slowfast/slowfast_model_history_log.csv", append=True)

    filepath="/content/drive/Shared drives/Drive 13/Dataset/Slowfast/slowfast-{epoch:02d}-{val_accuracy:.2f}.hd5"
    checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, mode='max')
    callbacks_list = [checkpoint, csv_logger]

    history = model.fit(batchGenerator(X_train, Y_train, batch_size, vid3d), steps_per_epoch = math.ceil(len(X_train) / batch_size), 
                                  validation_data = batchGenerator(X_val, Y_val, batch_size, vid3d), validation_steps = math.ceil(len(X_val) / batch_size), 
                                  epochs = epochs, verbose = 1, callbacks=callbacks_list, initial_epoch = 0)

    model_json = model.to_json()
    
    if not os.path.isdir(result_dir):
        os.makedir(result_dir)
    with open(os.path.join(result_dir, 'slowfast.json'), 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights(os.path.join(result_dir, 'slowfast_finalweights.hd5'))

    model.save("slowfast_finalmodel.hd5")

    loss, acc = model.evaluate(batchGenerator(X_test, Y_test, batch_size, vid3d),
                               steps = math.ceil(len(X_test) / batch_size), verbose = 1)
    
    plot_history(history, result_dir)

    print('Test loss:', loss)
    print('Test accuracy:', acc)

    return history, model

# %%
## TRAIN MODEL ##

history, model = main(video_dir = 'DCSASS Dataset/', result_dir = 'output/', nb_classes = 14, batch_size = 8, epochs = 100, img_size = 224, frames = 25)
# Out:
# X_shape:533	Y_shape:(533, 14)
# Input Shape =  (25, 224, 224, 3)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 25, 224, 22  0           []
#                                 4, 3)]
#
#  data_fast (Lambda)             (None, 13, 224, 224  0           ['input_1[0][0]']
#                                 , 3)
#
#  data_slow (Lambda)             (None, 2, 224, 224,  0           ['input_1[0][0]']
#                                  3)
#
#  sequential (Sequential)        (None, 13, 112, 112  5912        ['data_fast[0][0]']
#                                 , 8)
#
#  sequential_37 (Sequential)     (None, 2, 112, 112,  9664        ['data_slow[0][0]']
#                                  64)
#
#  max_pooling3d (MaxPooling3D)   (None, 13, 56, 56,   0           ['sequential[0][0]']
#                                 8)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 2, 56, 56, 6  0          ['sequential_37[0][0]']
#                                 4)
#
#  conv3d_1 (Conv3D)              (None, 2, 56, 56, 1  640         ['max_pooling3d[0][0]']
#                                 6)
#
#  concatenate (Concatenate)      (None, 2, 56, 56, 8  0           ['max_pooling3d_1[0][0]',
#                                 0)                                'conv3d_1[0][0]']
#
#  sequential_2 (Sequential)      (None, 13, 56, 56,   224         ['max_pooling3d[0][0]']
#                                 8)
#
#  sequential_39 (Sequential)     (None, 2, 56, 56, 6  5376        ['concatenate[0][0]']
#                                 4)
#
#  sequential_3 (Sequential)      (None, 13, 56, 56,   608         ['sequential_2[0][0]']
#                                 8)
#
#  sequential_40 (Sequential)     (None, 2, 56, 56, 6  37120       ['sequential_39[0][0]']
#                                 4)
#
#  conv3d_5 (Conv3D)              (None, 13, 56, 56,   256         ['sequential_3[0][0]']
#                                 32)
#
#  conv3d_61 (Conv3D)             (None, 2, 56, 56, 2  16384       ['sequential_40[0][0]']
#                                 56)
#
#  batch_normalization_4 (BatchNo  (None, 13, 56, 56,   128        ['conv3d_5[0][0]']
#  rmalization)                   32)
#
#  sequential_1 (Sequential)      (None, 13, 56, 56,   384         ['max_pooling3d[0][0]']
#                                 32)
#
#  batch_normalization_57 (BatchN  (None, 2, 56, 56, 2  1024       ['conv3d_61[0][0]']
#  ormalization)                  56)
#
#  sequential_38 (Sequential)     (None, 2, 56, 56, 2  21504       ['concatenate[0][0]']
#                                 56)
#
#  add (Add)                      (None, 13, 56, 56,   0           ['batch_normalization_4[0][0]',
#                                 32)                               'sequential_1[0][0]']
#
#  add_16 (Add)                   (None, 2, 56, 56, 2  0           ['batch_normalization_57[0][0]',
#                                 56)                               'sequential_38[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 13, 56, 56,   0           ['add[0][0]']
#                                 32)
#
#  re_lu_52 (ReLU)                (None, 2, 56, 56, 2  0           ['add_16[0][0]']
#                                 56)
#
#  sequential_4 (Sequential)      (None, 13, 56, 56,   800         ['re_lu_3[0][0]']
#                                 8)
#
#  sequential_41 (Sequential)     (None, 2, 56, 56, 6  16640       ['re_lu_52[0][0]']
#                                 4)
#
#  sequential_5 (Sequential)      (None, 13, 56, 56,   608         ['sequential_4[0][0]']
#                                 8)
#
#  sequential_42 (Sequential)     (None, 2, 56, 56, 6  37120       ['sequential_41[0][0]']
#                                 4)
#
#  conv3d_8 (Conv3D)              (None, 13, 56, 56,   256         ['sequential_5[0][0]']
#                                 32)
#
#  conv3d_64 (Conv3D)             (None, 2, 56, 56, 2  16384       ['sequential_42[0][0]']
#                                 56)
#
#  batch_normalization_7 (BatchNo  (None, 13, 56, 56,   128        ['conv3d_8[0][0]']
#  rmalization)                   32)
#
#  batch_normalization_60 (BatchN  (None, 2, 56, 56, 2  1024       ['conv3d_64[0][0]']
#  ormalization)                  56)
#
#  add_1 (Add)                    (None, 13, 56, 56,   0           ['batch_normalization_7[0][0]',
#                                 32)                               're_lu_3[0][0]']
#
#  add_17 (Add)                   (None, 2, 56, 56, 2  0           ['batch_normalization_60[0][0]',
#                                 56)                               're_lu_52[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 13, 56, 56,   0           ['add_1[0][0]']
#                                 32)
#
#  re_lu_55 (ReLU)                (None, 2, 56, 56, 2  0           ['add_17[0][0]']
#                                 56)
#
#  sequential_6 (Sequential)      (None, 13, 56, 56,   800         ['re_lu_6[0][0]']
#                                 8)
#
#  sequential_43 (Sequential)     (None, 2, 56, 56, 6  16640       ['re_lu_55[0][0]']
#                                 4)
#
#  sequential_7 (Sequential)      (None, 13, 56, 56,   608         ['sequential_6[0][0]']
#                                 8)
#
#  sequential_44 (Sequential)     (None, 2, 56, 56, 6  37120       ['sequential_43[0][0]']
#                                 4)
#
#  conv3d_11 (Conv3D)             (None, 13, 56, 56,   256         ['sequential_7[0][0]']
#                                 32)
#
#  conv3d_67 (Conv3D)             (None, 2, 56, 56, 2  16384       ['sequential_44[0][0]']
#                                 56)
#
#  batch_normalization_10 (BatchN  (None, 13, 56, 56,   128        ['conv3d_11[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_63 (BatchN  (None, 2, 56, 56, 2  1024       ['conv3d_67[0][0]']
#  ormalization)                  56)
#
#  add_2 (Add)                    (None, 13, 56, 56,   0           ['batch_normalization_10[0][0]',
#                                 32)                               're_lu_6[0][0]']
#
#  add_18 (Add)                   (None, 2, 56, 56, 2  0           ['batch_normalization_63[0][0]',
#                                 56)                               're_lu_55[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 13, 56, 56,   0           ['add_2[0][0]']
#                                 32)
#
#  re_lu_58 (ReLU)                (None, 2, 56, 56, 2  0           ['add_18[0][0]']
#                                 56)
#
#  conv3d_12 (Conv3D)             (None, 2, 56, 56, 6  10240       ['re_lu_9[0][0]']
#                                 4)
#
#  concatenate_1 (Concatenate)    (None, 2, 56, 56, 3  0           ['re_lu_58[0][0]',
#                                 20)                               'conv3d_12[0][0]']
#
#  sequential_9 (Sequential)      (None, 13, 56, 56,   1600        ['re_lu_9[0][0]']
#                                 16)
#
#  sequential_46 (Sequential)     (None, 2, 56, 56, 1  41472       ['concatenate_1[0][0]']
#                                 28)
#
#  sequential_10 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_9[0][0]']
#                                 16)
#
#  sequential_47 (Sequential)     (None, 2, 28, 28, 1  147968      ['sequential_46[0][0]']
#                                 28)
#
#  conv3d_16 (Conv3D)             (None, 13, 28, 28,   1024        ['sequential_10[0][0]']
#                                 64)
#
#  conv3d_71 (Conv3D)             (None, 2, 28, 28, 5  65536       ['sequential_47[0][0]']
#                                 12)
#
#  batch_normalization_14 (BatchN  (None, 13, 28, 28,   256        ['conv3d_16[0][0]']
#  ormalization)                  64)
#
#  sequential_8 (Sequential)      (None, 13, 28, 28,   2304        ['re_lu_9[0][0]']
#                                 64)
#
#  batch_normalization_67 (BatchN  (None, 2, 28, 28, 5  2048       ['conv3d_71[0][0]']
#  ormalization)                  12)
#
#  sequential_45 (Sequential)     (None, 2, 28, 28, 5  165888      ['concatenate_1[0][0]']
#                                 12)
#
#  add_3 (Add)                    (None, 13, 28, 28,   0           ['batch_normalization_14[0][0]',
#                                 64)                               'sequential_8[0][0]']
#
#  add_19 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_67[0][0]',
#                                 12)                               'sequential_45[0][0]']
#
#  re_lu_12 (ReLU)                (None, 13, 28, 28,   0           ['add_3[0][0]']
#                                 64)
#
#  re_lu_61 (ReLU)                (None, 2, 28, 28, 5  0           ['add_19[0][0]']
#                                 12)
#
#  sequential_11 (Sequential)     (None, 13, 28, 28,   3136        ['re_lu_12[0][0]']
#                                 16)
#
#  sequential_48 (Sequential)     (None, 2, 28, 28, 1  66048       ['re_lu_61[0][0]']
#                                 28)
#
#  sequential_12 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_11[0][0]']
#                                 16)
#
#  sequential_49 (Sequential)     (None, 2, 28, 28, 1  147968      ['sequential_48[0][0]']
#                                 28)
#
#  conv3d_19 (Conv3D)             (None, 13, 28, 28,   1024        ['sequential_12[0][0]']
#                                 64)
#
#  conv3d_74 (Conv3D)             (None, 2, 28, 28, 5  65536       ['sequential_49[0][0]']
#                                 12)
#
#  batch_normalization_17 (BatchN  (None, 13, 28, 28,   256        ['conv3d_19[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_70 (BatchN  (None, 2, 28, 28, 5  2048       ['conv3d_74[0][0]']
#  ormalization)                  12)
#
#  add_4 (Add)                    (None, 13, 28, 28,   0           ['batch_normalization_17[0][0]',
#                                 64)                               're_lu_12[0][0]']
#
#  add_20 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_70[0][0]',
#                                 12)                               're_lu_61[0][0]']
#
#  re_lu_15 (ReLU)                (None, 13, 28, 28,   0           ['add_4[0][0]']
#                                 64)
#
#  re_lu_64 (ReLU)                (None, 2, 28, 28, 5  0           ['add_20[0][0]']
#                                 12)
#
#  sequential_13 (Sequential)     (None, 13, 28, 28,   3136        ['re_lu_15[0][0]']
#                                 16)
#
#  sequential_50 (Sequential)     (None, 2, 28, 28, 1  66048       ['re_lu_64[0][0]']
#                                 28)
#
#  sequential_14 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_13[0][0]']
#                                 16)
#
#  sequential_51 (Sequential)     (None, 2, 28, 28, 1  147968      ['sequential_50[0][0]']
#                                 28)
#
#  conv3d_22 (Conv3D)             (None, 13, 28, 28,   1024        ['sequential_14[0][0]']
#                                 64)
#
#  conv3d_77 (Conv3D)             (None, 2, 28, 28, 5  65536       ['sequential_51[0][0]']
#                                 12)
#
#  batch_normalization_20 (BatchN  (None, 13, 28, 28,   256        ['conv3d_22[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_73 (BatchN  (None, 2, 28, 28, 5  2048       ['conv3d_77[0][0]']
#  ormalization)                  12)
#
#  add_5 (Add)                    (None, 13, 28, 28,   0           ['batch_normalization_20[0][0]',
#                                 64)                               're_lu_15[0][0]']
#
#  add_21 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_73[0][0]',
#                                 12)                               're_lu_64[0][0]']
#
#  re_lu_18 (ReLU)                (None, 13, 28, 28,   0           ['add_5[0][0]']
#                                 64)
#
#  re_lu_67 (ReLU)                (None, 2, 28, 28, 5  0           ['add_21[0][0]']
#                                 12)
#
#  sequential_15 (Sequential)     (None, 13, 28, 28,   3136        ['re_lu_18[0][0]']
#                                 16)
#
#  sequential_52 (Sequential)     (None, 2, 28, 28, 1  66048       ['re_lu_67[0][0]']
#                                 28)
#
#  sequential_16 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_15[0][0]']
#                                 16)
#
#  sequential_53 (Sequential)     (None, 2, 28, 28, 1  147968      ['sequential_52[0][0]']
#                                 28)
#
#  conv3d_25 (Conv3D)             (None, 13, 28, 28,   1024        ['sequential_16[0][0]']
#                                 64)
#
#  conv3d_80 (Conv3D)             (None, 2, 28, 28, 5  65536       ['sequential_53[0][0]']
#                                 12)
#
#  batch_normalization_23 (BatchN  (None, 13, 28, 28,   256        ['conv3d_25[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_76 (BatchN  (None, 2, 28, 28, 5  2048       ['conv3d_80[0][0]']
#  ormalization)                  12)
#
#  add_6 (Add)                    (None, 13, 28, 28,   0           ['batch_normalization_23[0][0]',
#                                 64)                               're_lu_18[0][0]']
#
#  add_22 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_76[0][0]',
#                                 12)                               're_lu_67[0][0]']
#
#  re_lu_21 (ReLU)                (None, 13, 28, 28,   0           ['add_6[0][0]']
#                                 64)
#
#  re_lu_70 (ReLU)                (None, 2, 28, 28, 5  0           ['add_22[0][0]']
#                                 12)
#
#  conv3d_26 (Conv3D)             (None, 2, 28, 28, 1  40960       ['re_lu_21[0][0]']
#                                 28)
#
#  concatenate_2 (Concatenate)    (None, 2, 28, 28, 6  0           ['re_lu_70[0][0]',
#                                 40)                               'conv3d_26[0][0]']
#
#  sequential_18 (Sequential)     (None, 13, 28, 28,   6272        ['re_lu_21[0][0]']
#                                 32)
#
#  sequential_55 (Sequential)     (None, 2, 28, 28, 2  164864      ['concatenate_2[0][0]']
#                                 56)
#
#  sequential_19 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_18[0][0]']
#                                 32)
#
#  sequential_56 (Sequential)     (None, 2, 14, 14, 2  590848      ['sequential_55[0][0]']
#                                 56)
#
#  conv3d_30 (Conv3D)             (None, 13, 14, 14,   4096        ['sequential_19[0][0]']
#                                 128)
#
#  conv3d_84 (Conv3D)             (None, 2, 14, 14, 1  262144      ['sequential_56[0][0]']
#                                 024)
#
#  batch_normalization_27 (BatchN  (None, 13, 14, 14,   512        ['conv3d_30[0][0]']
#  ormalization)                  128)
#
#  sequential_17 (Sequential)     (None, 13, 14, 14,   8704        ['re_lu_21[0][0]']
#                                 128)
#
#  batch_normalization_80 (BatchN  (None, 2, 14, 14, 1  4096       ['conv3d_84[0][0]']
#  ormalization)                  024)
#
#  sequential_54 (Sequential)     (None, 2, 14, 14, 1  659456      ['concatenate_2[0][0]']
#                                 024)
#
#  add_7 (Add)                    (None, 13, 14, 14,   0           ['batch_normalization_27[0][0]',
#                                 128)                              'sequential_17[0][0]']
#
#  add_23 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_80[0][0]',
#                                 024)                              'sequential_54[0][0]']
#
#  re_lu_24 (ReLU)                (None, 13, 14, 14,   0           ['add_7[0][0]']
#                                 128)
#
#  re_lu_73 (ReLU)                (None, 2, 14, 14, 1  0           ['add_23[0][0]']
#                                 024)
#
#  sequential_20 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_24[0][0]']
#                                 32)
#
#  sequential_57 (Sequential)     (None, 2, 14, 14, 2  263168      ['re_lu_73[0][0]']
#                                 56)
#
#  sequential_21 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_20[0][0]']
#                                 32)
#
#  sequential_58 (Sequential)     (None, 2, 14, 14, 2  590848      ['sequential_57[0][0]']
#                                 56)
#
#  conv3d_33 (Conv3D)             (None, 13, 14, 14,   4096        ['sequential_21[0][0]']
#                                 128)
#
#  conv3d_87 (Conv3D)             (None, 2, 14, 14, 1  262144      ['sequential_58[0][0]']
#                                 024)
#
#  batch_normalization_30 (BatchN  (None, 13, 14, 14,   512        ['conv3d_33[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_83 (BatchN  (None, 2, 14, 14, 1  4096       ['conv3d_87[0][0]']
#  ormalization)                  024)
#
#  add_8 (Add)                    (None, 13, 14, 14,   0           ['batch_normalization_30[0][0]',
#                                 128)                              're_lu_24[0][0]']
#
#  add_24 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_83[0][0]',
#                                 024)                              're_lu_73[0][0]']
#
#  re_lu_27 (ReLU)                (None, 13, 14, 14,   0           ['add_8[0][0]']
#                                 128)
#
#  re_lu_76 (ReLU)                (None, 2, 14, 14, 1  0           ['add_24[0][0]']
#                                 024)
#
#  sequential_22 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_27[0][0]']
#                                 32)
#
#  sequential_59 (Sequential)     (None, 2, 14, 14, 2  263168      ['re_lu_76[0][0]']
#                                 56)
#
#  sequential_23 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_22[0][0]']
#                                 32)
#
#  sequential_60 (Sequential)     (None, 2, 14, 14, 2  590848      ['sequential_59[0][0]']
#                                 56)
#
#  conv3d_36 (Conv3D)             (None, 13, 14, 14,   4096        ['sequential_23[0][0]']
#                                 128)
#
#  conv3d_90 (Conv3D)             (None, 2, 14, 14, 1  262144      ['sequential_60[0][0]']
#                                 024)
#
#  batch_normalization_33 (BatchN  (None, 13, 14, 14,   512        ['conv3d_36[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_86 (BatchN  (None, 2, 14, 14, 1  4096       ['conv3d_90[0][0]']
#  ormalization)                  024)
#
#  add_9 (Add)                    (None, 13, 14, 14,   0           ['batch_normalization_33[0][0]',
#                                 128)                              're_lu_27[0][0]']
#
#  add_25 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_86[0][0]',
#                                 024)                              're_lu_76[0][0]']
#
#  re_lu_30 (ReLU)                (None, 13, 14, 14,   0           ['add_9[0][0]']
#                                 128)
#
#  re_lu_79 (ReLU)                (None, 2, 14, 14, 1  0           ['add_25[0][0]']
#                                 024)
#
#  sequential_24 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_30[0][0]']
#                                 32)
#
#  sequential_61 (Sequential)     (None, 2, 14, 14, 2  263168      ['re_lu_79[0][0]']
#                                 56)
#
#  sequential_25 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_24[0][0]']
#                                 32)
#
#  sequential_62 (Sequential)     (None, 2, 14, 14, 2  590848      ['sequential_61[0][0]']
#                                 56)
#
#  conv3d_39 (Conv3D)             (None, 13, 14, 14,   4096        ['sequential_25[0][0]']
#                                 128)
#
#  conv3d_93 (Conv3D)             (None, 2, 14, 14, 1  262144      ['sequential_62[0][0]']
#                                 024)
#
#  batch_normalization_36 (BatchN  (None, 13, 14, 14,   512        ['conv3d_39[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_89 (BatchN  (None, 2, 14, 14, 1  4096       ['conv3d_93[0][0]']
#  ormalization)                  024)
#
#  add_10 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_36[0][0]',
#                                 128)                              're_lu_30[0][0]']
#
#  add_26 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_89[0][0]',
#                                 024)                              're_lu_79[0][0]']
#
#  re_lu_33 (ReLU)                (None, 13, 14, 14,   0           ['add_10[0][0]']
#                                 128)
#
#  re_lu_82 (ReLU)                (None, 2, 14, 14, 1  0           ['add_26[0][0]']
#                                 024)
#
#  sequential_26 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_33[0][0]']
#                                 32)
#
#  sequential_63 (Sequential)     (None, 2, 14, 14, 2  263168      ['re_lu_82[0][0]']
#                                 56)
#
#  sequential_27 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_26[0][0]']
#                                 32)
#
#  sequential_64 (Sequential)     (None, 2, 14, 14, 2  590848      ['sequential_63[0][0]']
#                                 56)
#
#  conv3d_42 (Conv3D)             (None, 13, 14, 14,   4096        ['sequential_27[0][0]']
#                                 128)
#
#  conv3d_96 (Conv3D)             (None, 2, 14, 14, 1  262144      ['sequential_64[0][0]']
#                                 024)
#
#  batch_normalization_39 (BatchN  (None, 13, 14, 14,   512        ['conv3d_42[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_92 (BatchN  (None, 2, 14, 14, 1  4096       ['conv3d_96[0][0]']
#  ormalization)                  024)
#
#  add_11 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_39[0][0]',
#                                 128)                              're_lu_33[0][0]']
#
#  add_27 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_92[0][0]',
# ...
#                                 56)
#
#  concatenate_3 (Concatenate)    (None, 2, 14, 14, 1  0           ['re_lu_88[0][0]',
#                                 280)                              'conv3d_46[0][0]']
#
#  sequential_68 (Sequential)     (None, 2, 14, 14, 5  657408      ['concatenate_3[0][0]']
#                                 12)
#
#  sequential_31 (Sequential)     (None, 13, 14, 14,   24832       ['re_lu_39[0][0]']
#                                 64)
#
#  sequential_69 (Sequential)     (None, 2, 7, 7, 512  2361344     ['sequential_68[0][0]']
#                                 )
#
#  sequential_32 (Sequential)     (None, 13, 7, 7, 64  37120       ['sequential_31[0][0]']
#                                 )
#
#  conv3d_103 (Conv3D)            (None, 2, 7, 7, 204  1048576     ['sequential_69[0][0]']
#                                 8)
#
#  conv3d_50 (Conv3D)             (None, 13, 7, 7, 25  16384       ['sequential_32[0][0]']
#                                 6)
#
#  batch_normalization_99 (BatchN  (None, 2, 7, 7, 204  8192       ['conv3d_103[0][0]']
#  ormalization)                  8)
#
#  sequential_67 (Sequential)     (None, 2, 7, 7, 204  2629632     ['concatenate_3[0][0]']
#                                 8)
#
#  batch_normalization_46 (BatchN  (None, 13, 7, 7, 25  1024       ['conv3d_50[0][0]']
#  ormalization)                  6)
#
#  sequential_30 (Sequential)     (None, 13, 7, 7, 25  33792       ['re_lu_39[0][0]']
#                                 6)
#
#  add_29 (Add)                   (None, 2, 7, 7, 204  0           ['batch_normalization_99[0][0]',
#                                 8)                                'sequential_67[0][0]']
#
#  add_13 (Add)                   (None, 13, 7, 7, 25  0           ['batch_normalization_46[0][0]',
#                                 6)                                'sequential_30[0][0]']
#
#  re_lu_91 (ReLU)                (None, 2, 7, 7, 204  0           ['add_29[0][0]']
#                                 8)
#
#  re_lu_42 (ReLU)                (None, 13, 7, 7, 25  0           ['add_13[0][0]']
#                                 6)
#
#  sequential_70 (Sequential)     (None, 2, 7, 7, 512  1050624     ['re_lu_91[0][0]']
#                                 )
#
#  sequential_33 (Sequential)     (None, 13, 7, 7, 64  49408       ['re_lu_42[0][0]']
#                                 )
#
#  sequential_71 (Sequential)     (None, 2, 7, 7, 512  2361344     ['sequential_70[0][0]']
#                                 )
#
#  sequential_34 (Sequential)     (None, 13, 7, 7, 64  37120       ['sequential_33[0][0]']
#                                 )
#
#  conv3d_106 (Conv3D)            (None, 2, 7, 7, 204  1048576     ['sequential_71[0][0]']
#                                 8)
#
#  conv3d_53 (Conv3D)             (None, 13, 7, 7, 25  16384       ['sequential_34[0][0]']
#                                 6)
#
#  batch_normalization_102 (Batch  (None, 2, 7, 7, 204  8192       ['conv3d_106[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_49 (BatchN  (None, 13, 7, 7, 25  1024       ['conv3d_53[0][0]']
#  ormalization)                  6)
#
#  add_30 (Add)                   (None, 2, 7, 7, 204  0           ['batch_normalization_102[0][0]',
#                                 8)                                're_lu_91[0][0]']
#
#  add_14 (Add)                   (None, 13, 7, 7, 25  0           ['batch_normalization_49[0][0]',
#                                 6)                                're_lu_42[0][0]']
#
#  re_lu_94 (ReLU)                (None, 2, 7, 7, 204  0           ['add_30[0][0]']
#                                 8)
#
#  re_lu_45 (ReLU)                (None, 13, 7, 7, 25  0           ['add_14[0][0]']
#                                 6)
#
#  sequential_72 (Sequential)     (None, 2, 7, 7, 512  1050624     ['re_lu_94[0][0]']
#                                 )
#
#  sequential_35 (Sequential)     (None, 13, 7, 7, 64  49408       ['re_lu_45[0][0]']
#                                 )
#
#  sequential_73 (Sequential)     (None, 2, 7, 7, 512  2361344     ['sequential_72[0][0]']
#                                 )
#
#  sequential_36 (Sequential)     (None, 13, 7, 7, 64  37120       ['sequential_35[0][0]']
#                                 )
#
#  conv3d_109 (Conv3D)            (None, 2, 7, 7, 204  1048576     ['sequential_73[0][0]']
#                                 8)
#
#  conv3d_56 (Conv3D)             (None, 13, 7, 7, 25  16384       ['sequential_36[0][0]']
#                                 6)
#
#  batch_normalization_105 (Batch  (None, 2, 7, 7, 204  8192       ['conv3d_109[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_52 (BatchN  (None, 13, 7, 7, 25  1024       ['conv3d_56[0][0]']
#  ormalization)                  6)
#
#  add_31 (Add)                   (None, 2, 7, 7, 204  0           ['batch_normalization_105[0][0]',
#                                 8)                                're_lu_94[0][0]']
#
#  add_15 (Add)                   (None, 13, 7, 7, 25  0           ['batch_normalization_52[0][0]',
#                                 6)                                're_lu_45[0][0]']
#
#  re_lu_97 (ReLU)                (None, 2, 7, 7, 204  0           ['add_31[0][0]']
#                                 8)
#
#  re_lu_48 (ReLU)                (None, 13, 7, 7, 25  0           ['add_15[0][0]']
#                                 6)
#
#  global_average_pooling3d_1 (Gl  (None, 2048)        0           ['re_lu_97[0][0]']
#  obalAveragePooling3D)
#
#  global_average_pooling3d (Glob  (None, 256)         0           ['re_lu_48[0][0]']
#  alAveragePooling3D)
#
#  concatenate_4 (Concatenate)    (None, 2304)         0           ['global_average_pooling3d_1[0][0
#                                                                  ]',
#                                                                   'global_average_pooling3d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 2304)         0           ['concatenate_4[0][0]']
#
#  dense (Dense)                  (None, 14)           32270       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 25,195,174
# Trainable params: 25,135,414
# Non-trainable params: 59,760
# __________________________________________________________________________________________________
# X_train.shape =  385
# X_val.shape =  68
# X_test.shape =  80
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 3
#       1 ## TRAIN MODEL ##
# ----> 3 history, model = main(video_dir = 'DCSASS Dataset/', result_dir = 'output/', nb_classes = 14, batch_size = 8, epochs = 100, img_size = 224, frames = 25)
#
# Cell In[8], line 50, in main(video_dir, result_dir, nb_classes, batch_size, epochs, img_size, frames)
#      47 checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, mode='max')
#      48 callbacks_list = [checkpoint, csv_logger]
# ---> 50 history = model.fit(batchGenerator(X_train, Y_train, batch_size, vid3d), steps_per_epoch = math.ceil(len(X_train) / batch_size),
#      51                               validation_data = batchGenerator(X_val, Y_val, batch_size, vid3d), validation_steps = math.ceil(len(X_val) / batch_size),
#      52                               epochs = epochs, verbose = 1, callbacks=callbacks_list, initial_epoch = 0)
#      54 model_json = model.to_json()
#      56 if not os.path.isdir(result_dir):
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In[7], line 15, in batchGenerator.__getitem__(self, idx)
#      12 batch_x = []
#      14 for video in self.x[idx * self.batch_size:(idx + 1) * self.batch_size]:
# ---> 15     batch_x.append(self.vid3d.video3d(video))
#      17 batch_x = np.array(batch_x)
#      18 batch_x = batch_x.astype('float32')
#
# Cell In[3], line 20, in Videoto3D.video3d(self, filename)
#      18     img_path = os.path.join(filename, img)
#      19     frame = cv2.imread(img_path)
# ---> 20     frame = cv2.resize(frame, (self.height, self.width))
#      21     frames.append(frame)
#      23 return np.array(frames) / 255.0
#
# error: OpenCV(4.10.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
def frames_from_video(video_dir, nb_frames = 25, img_size = 224):

    # Opens the Video file
    cap = cv2.VideoCapture(video_dir)
    i=0
    frames = []
    while(cap.isOpened() and i<nb_frames):
        ret, frame = cap.read()
        if ret == False:
            break
        frame = cv2.resize(frame, (img_size, img_size))
        frames.append(frame)
        i+=1

    cap.release()
    cv2.destroyAllWindows()
    return np.array(frames) / 255.0

# %%
def predictions(video_dir, model, nb_frames = 25, img_size = 224):

    X = frames_from_video(video_dir, nb_frames, img_size)
    X = np.reshape(X, (1, nb_frames, img_size, img_size, 3))
    
    predictions = model.predict(X)
    preds = predictions.argmax(axis = 1)

    classes = []
    with open(os.path.join('output', 'classes.txt'), 'r') as fp:
        for line in fp:
            classes.append(line.split()[1])

    for i in range(len(preds)):
        print('Prediction - {} -- {}'.format(preds[i], classes[preds[i]]))

# %%
import h5py

try:
    with h5py.File('slowfast_finalmodel.hd5', 'r') as f:
        print("File keys:", list(f.keys()))
except OSError as e:
    print("File is not a valid HDF5 file:", e)
# Out:
# File keys: ['model_weights', 'optimizer_weights']

# %%
## MAKE PREDICTIONS ##

# Ensure the model is loaded
if 'model' not in globals():
	from keras.models import load_model
	model = load_model('output/slowfast_finalmodel.hd5')

predictions(video_dir = 'test/Arrest048_x264_21.mp4', model = model, nb_frames = 25, img_size = 224)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[118], line 6
#       4 if 'model' not in globals():
#       5 	from keras.models import load_model
# ----> 6 	model = load_model('output/slowfast_finalmodel.hd5')
#       8 predictions(video_dir = 'test/Arrest048_x264_21.mp4', model = model, nb_frames = 25, img_size = 224)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/keras/utils/generic_utils.py:103, in func_load(code, defaults, closure, globs)
#     101 except (UnicodeEncodeError, binascii.Error):
#     102     raw_code = code.encode("raw_unicode_escape")
# --> 103 code = marshal.loads(raw_code)
#     104 if globs is None:
#     105     globs = globals()
#
# EOFError: EOF read where object expected

# %%
import os
import h5py
from keras.models import load_model

# Ensure the correct path to the model file
model_path = 'output/slowfast_finalmodel.hd5'

# Verify the file exists
if not os.path.exists(model_path):
    raise FileNotFoundError(f"No file found at {model_path}")

try:
    model = load_model(model_path)
except EOFError as e:
    print(f"Error loading model: {e}")
    # Handle the error or re-raise
    raise
# Out:
# Error loading model: EOF read where object expected
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[121], line 13
#      10     raise FileNotFoundError(f"No file found at {model_path}")
#      12 try:
# ---> 13     model = load_model(model_path)
#      14 except EOFError as e:
#      15     print(f"Error loading model: {e}")
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/keras/utils/generic_utils.py:103, in func_load(code, defaults, closure, globs)
#     101 except (UnicodeEncodeError, binascii.Error):
#     102     raw_code = code.encode("raw_unicode_escape")
# --> 103 code = marshal.loads(raw_code)
#     104 if globs is None:
#     105     globs = globals()
#
# EOFError: EOF read where object expected
